# %% [markdown]
# <a href="https://colab.research.google.com/github/Shravani3001/flipkart-csat-ml-project/blob/main/notebooks/Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Flipkart Customer Support CSAT Score Analysis and Prediction

# %% [markdown]
# ##### **Project Type**    - EDA + Classification
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Shravani K
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Customer satisfaction is one of the most important factors that determines the success of any e-commerce platform. In a highly competitive online retail environment, companies like Flipkart must ensure that customers receive quick and effective support when they face issues related to orders, deliveries, payments, or product returns. A positive customer support experience can significantly improve customer loyalty, while poor support service may lead to dissatisfaction and customer churn. Therefore, analyzing customer satisfaction data and understanding the factors that influence it is crucial for improving service quality and overall business performance.
#
# This project focuses on analyzing customer support interaction data to understand the factors that affect Customer Satisfaction Scores (CSAT). The dataset contains information about various customer support interactions, including details such as issue categories, support channels used by customers, response times from support agents, product categories, and other operational attributes. Each record represents a customer interaction along with the CSAT score provided by the customer after the issue was resolved. These scores help measure how satisfied customers are with the support service they received.
#
# The first stage of the project involves performing Exploratory Data Analysis (EDA) to gain insights into the dataset and identify patterns that influence customer satisfaction. During this stage, data cleaning and preprocessing are carried out to handle missing values, incorrect data types, and inconsistencies in the dataset. Various visualization techniques and statistical methods are used to explore relationships between different variables and the CSAT score. For example, the analysis investigates how response time affects customer satisfaction, whether certain issue categories lead to lower satisfaction scores, and how different support channels such as chat, email, or phone influence the overall customer experience.
#
# Through EDA, meaningful insights are generated about operational factors that may contribute to higher or lower customer satisfaction. For instance, longer response times may result in lower CSAT scores, while faster issue resolution may improve customer experience. Similarly, certain issue types or product categories might require better support processes. Identifying these patterns helps businesses understand where improvements are needed in the customer support system.
#
# In the next stage of the project, machine learning techniques are applied to build a predictive model that can estimate customer satisfaction scores based on the available features in the dataset. By training classification models on historical support interaction data, the system can learn patterns that influence customer satisfaction. Once trained, the model can predict whether a customer interaction is likely to result in a high or low satisfaction score.
#
# This predictive capability can help businesses proactively identify potentially dissatisfied customers and take corrective actions before the situation escalates. For example, support teams can prioritize cases that are more likely to lead to dissatisfaction or improve processes that frequently result in low CSAT scores. Ultimately, this project demonstrates how data analysis and machine learning can be used to enhance customer support performance, improve customer experience, and support data-driven decision making in an e-commerce environment.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Shravani3001/flipkart-csat-ml-project.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Customer support is a critical component of customer experience in e-commerce platforms. Companies receive a large number of customer queries related to orders, returns, payments, and product information. However, not all support interactions result in high customer satisfaction.
#
# The challenge is to analyze customer support data and identify the key factors that influence customer satisfaction (CSAT). Understanding these factors will help businesses improve their support services, reduce customer frustration, and deliver a better overall experience.
#
# Therefore, the goal of this project is to explore the dataset, understand the relationships between different variables, and build a predictive model that can estimate customer satisfaction scores based on support interaction details.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main business objective of this project is to improve customer satisfaction by identifying the operational and service-related factors that influence CSAT scores. By analyzing customer support interactions, the company can understand which aspects of the support process contribute positively or negatively to customer satisfaction.
#
# The insights from this analysis can help businesses optimize support channels, reduce response times, improve issue resolution processes, and enhance agent performance. Additionally, building a predictive model for CSAT scores allows the company to anticipate customer satisfaction levels and take proactive actions to improve the customer experience.
#
# Ultimately, the goal is to improve service quality, increase customer loyalty, and support long-term business growth.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# These libraries are used for data manipulation (pandas, numpy) and data visualization (matplotlib, seaborn).

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("/content/Customer_support_data.csv", encoding='latin-1')

# %% [markdown]
# The dataset is loaded using pandas. The encoding latin-1 is used to avoid encoding errors while reading the dataset.

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# This displays the first five rows of the dataset and helps understand the structure of the data.

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape

# %% [markdown]
# This shows the number of rows and columns present in the dataset.

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# This provides information about:
#
# - Column names
#
# - Data types
#
# - Non-null values
#
# - Memory usage

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()

# %% [markdown]
# This checks the number of duplicate rows present in the dataset.

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()

# %% [markdown]
# This shows the number of missing values in each column.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# The heatmap visually shows where missing values exist in the dataset.

# %% [markdown]
# ## **Observations on Missing Values**
#
# - The dataset contains several columns with missing values.
# - Columns such as Customer Remarks, order_date_time, Customer_City, Product_category, and Item_price contain a large number of missing entries.
# - The column connected_handling_time has extremely high missing values (85665 out of 85907), making it unsuitable for analysis.
# - Columns like Unique id, channel_name, category, Sub-category, Issue_reported_at, issue_responded, Survey_response_Date, Agent_name, Supervisor, Manager, Tenure Bucket, Agent Shift, and CSAT Score have no missing values.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# - The dataset contains **85,907 customer support interactions** with **20** **columns**.
#
# - Most columns are categorical variables representing **support channel, issue category, product category, and agent details.**
#
# - The target variable is **CSAT Score**, representing customer satisfaction.
#
#  - Some columns contain **significant missing values**, such as **connected_handling_time**, which has only 242 valid entries.
#
# - Identifier columns like Unique id and Order_id do not contribute to predicting satisfaction and will be removed during preprocessing.
#
# - Timestamp columns like Issue_reported_at and issue_responded can be used to derive **response time features**, which may influence customer satisfaction.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns

# %%
df.describe()

# %% [markdown]
# describe() provides summary statistics such as:
#
# - mean
#
# - standard deviation
#
# - minimum and maximum values
#
# - quartiles
#
# for numerical columns.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - Unique id – Unique identifier for each customer interaction.
#
# - Channel_name – Channel through which the customer contacted support (Inbound/Outcall).
#
# - Category – Broad category of the customer issue.
#
# - Sub-category – More detailed classification of the issue.
#
# - Customer Remarks – Feedback or remarks provided by the customer.
#
# - Order_id – Unique identifier of the related order.
#
# - Order_date_time – Date and time when the order was placed.
#
# - Issue_reported_at – Timestamp when the customer reported the issue.
#
# - Issue_responded – Timestamp when the issue was responded to by the support agent.
#
# - Survey_response_Date – Date when the customer submitted the satisfaction survey.
#
# - Customer_City – City of the customer.
#
# - Product_category – Category of the product associated with the issue.
#
# - Item_price – Price of the purchased product.
#
# - Connected_handling_time – Duration taken by the agent to handle the issue.
#
# - Agent_name – Name of the customer service agent.
#
# - Supervisor – Supervisor responsible for the agent.
#
# - Manager – Manager responsible for the supervisor.
#
# - Tenure Bucket – Experience level of the agent.
#
# - Agent Shift – Shift during which the agent handled the issue.
#
# - CSAT Score – Customer Satisfaction Score provided by the customer.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for col in df.columns:
    print(col, ":", df[col].nunique())

# %% [markdown]
# This helps understand how many unique values each column contains, which is useful for identifying categorical variables and potential data issues.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Create a copy of dataset
df_clean = df.copy()

# Convert date columns to datetime
df_clean['Issue_reported at'] = pd.to_datetime(df_clean['Issue_reported at'], errors='coerce')
df_clean['issue_responded'] = pd.to_datetime(df_clean['issue_responded'], errors='coerce')

# Create response time feature
df_clean['response_time_minutes'] = (
    df_clean['issue_responded'] - df_clean['Issue_reported at']
).dt.total_seconds() / 60

# Drop columns with extremely high missing values
df_clean = df_clean.drop(columns=['connected_handling_time'])

# Check dataset after wrangling
df_clean.head()

# %% [markdown]
# **Data Wrangling Steps**
#
# - Created a copy of the dataset to perform cleaning operations.
#
# - Converted timestamp columns Issue_reported_at and issue_responded to datetime format.
#
# - Generated a new feature response_time_minutes by calculating the difference between issue response time and issue reported time.
#
# - Removed the column connected_handling_time because it contained extremely high missing values.
#
# - Prepared the dataset for further exploratory data analysis.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Insights from Data Wrangling**
#
# - Timestamp columns can be used to derive meaningful features like response time, which may influence customer satisfaction.
#
# - Some columns contain excessive missing values and may not contribute meaningfully to analysis.
#
# - Creating derived features from existing data can help reveal patterns affecting CSAT scores.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='CSAT Score', data=df)
plt.title("Distribution of CSAT Score")
plt.xlabel("CSAT Score")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was used to visualize the distribution of CSAT scores because it clearly shows how frequently each satisfaction rating occurs in the dataset. This helps in understanding the overall customer satisfaction level and whether the dataset is balanced across different CSAT score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how customer satisfaction ratings are distributed across the dataset. It helps identify whether most customers are satisfied or dissatisfied with the support service. If higher CSAT scores (4 or 5) dominate, it indicates generally positive customer experiences. If lower scores appear frequently, it may suggest issues in the support process that require improvement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from this chart can help create a positive business impact. By understanding how CSAT scores are distributed, the company can evaluate the overall quality of customer support services. If most customers give high ratings (4 or 5), it indicates that the support system is performing well and maintaining good customer satisfaction. This helps the business maintain customer loyalty and strengthen its brand reputation.
#
# However, if there are a significant number of low CSAT scores (1 or 2), it indicates potential problems in customer service such as slow response times, ineffective issue resolution, or lack of proper support from agents. These issues can negatively affect customer experience, leading to customer dissatisfaction, reduced trust in the platform, and possible loss of customers to competitors.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='channel_name', data=df)
plt.title("Distribution of Customer Support Channels")
plt.xlabel("Channel Name")
plt.ylabel("Number of Interactions")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen to visualize the distribution of customer support channels. This chart helps understand which communication channels customers most frequently use when contacting customer support.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of customer support interactions across different channels such as Inbound and Outcall. It helps identify which channel is most commonly used by customers to report issues or seek assistance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can help create a positive business impact. By understanding which support channel customers use most frequently, the company can allocate resources more efficiently. For example, if most interactions occur through the inbound channel, the company can assign more support agents to handle inbound requests, improving response time and customer satisfaction.
#
# However, if one channel is overloaded with a large number of interactions while other channels are underutilized, it may indicate inefficiencies in the support system. This imbalance could lead to longer waiting times, delayed responses, and customer dissatisfaction. If customers repeatedly experience slow service through heavily used channels, it may negatively affect customer experience and lead to lower CSAT scores or potential loss of customers.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='category', data=df)
plt.title("Distribution of Issue Categories")
plt.xlabel("Issue Category")
plt.ylabel("Number of Customer Issues")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was chosen to visualize the distribution of issue categories. This chart helps identify which types of customer issues occur most frequently in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of customer support interactions for each issue category. It helps identify the most common problems customers face while using the platform, such as product queries, order-related issues, returns, or cancellations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can help create a positive business impact. By identifying the most common issue categories, the company can focus on improving those specific areas. For example, if order-related issues are the most frequent, the company can improve order tracking systems or logistics processes.
#
# However, if certain issue categories occur very frequently, it may indicate underlying operational problems such as delayed deliveries, product quality issues, or inefficient customer support processes. These problems could negatively impact customer satisfaction and lead to lower CSAT scores if not addressed.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(10,6))

top_subcats = df['Sub-category'].value_counts().head(10)

sns.barplot(x=top_subcats.values, y=top_subcats.index)

plt.title("Top 10 Issue Sub-Categories")
plt.xlabel("Number of Issues")
plt.ylabel("Sub-Category")

plt.show()

# %% [markdown]
# **Only the top 10 sub-categories were visualized to avoid overcrowding and to focus on the most frequently occurring customer issues.**

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was used to visualize the distribution of issue sub-categories. This chart helps identify the most frequent specific issues reported by customers within each broader category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of customer complaints or queries for each issue sub-category. It helps identify the most common specific problems customers face, such as delayed delivery, refund requests, or product damage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can help create a positive business impact. By identifying the most common sub-category issues, the company can focus on improving those specific areas. For example, if delayed delivery appears frequently, the company can improve logistics and delivery operations.
#
# However, if certain sub-categories consistently show a high number of complaints, it may indicate recurring operational problems such as poor product quality, inefficient return processes, or slow customer service responses. These issues could negatively affect customer satisfaction and may lead to lower CSAT scores or loss of customers if not addressed.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(10,6))

top_products = df['Product_category'].value_counts().head(10)

sns.barplot(x=top_products.values, y=top_products.index)

plt.title("Top 10 Product Categories in Customer Support Issues")
plt.xlabel("Number of Issues")
plt.ylabel("Product Category")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was used to visualize the distribution of product categories associated with customer support issues. Since there are many product categories, the top 10 categories were selected to make the visualization clearer and easier to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the most common product categories associated with customer support interactions. It helps identify which types of products generate the highest number of customer complaints or queries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can help create a positive business impact. By identifying product categories that generate the highest number of customer support issues, the company can focus on improving product quality, packaging, delivery, or after-sales service for those categories.
#
# However, if certain product categories consistently generate a large number of complaints, it may indicate deeper operational problems such as poor product quality, defective items, or inefficient delivery processes. If these issues are not addressed, they could negatively affect customer satisfaction and lead to lower CSAT scores or loss of customer trust.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(10,6))

avg_csat_category = df.groupby('category')['CSAT Score'].mean().sort_values(ascending=False)

sns.barplot(x=avg_csat_category.values, y=avg_csat_category.index)

plt.title("Average CSAT Score by Issue Category")
plt.xlabel("Average CSAT Score")
plt.ylabel("Issue Category")

plt.xlim(1,5)
plt.xticks([1,2,3,4,5])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected to analyze the relationship between issue categories and customer satisfaction scores. This chart helps compare the average CSAT score across different issue categories and makes it easier to identify which types of issues result in higher or lower customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that customer satisfaction varies across different issue categories. Some categories have higher average CSAT scores, indicating that customer issues in those areas are resolved effectively. Other categories show relatively lower CSAT scores, suggesting that customers may experience more difficulty or delays when dealing with those types of issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can help create a positive business impact. By identifying which issue categories result in lower customer satisfaction, the company can focus on improving the processes related to those specific issues. Enhancing problem resolution in these categories can improve customer experience and increase overall satisfaction.
#
# If certain issue categories consistently show lower CSAT scores, it may indicate operational inefficiencies such as delays in order handling, refund processing, or complaint resolution. If these problems are not addressed, they could negatively affect customer satisfaction and potentially lead to reduced customer loyalty or negative brand perception.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(8,5))

sns.barplot(x='Agent Shift', y='CSAT Score', data=df)

plt.title("Average CSAT Score by Agent Shift")
plt.xlabel("Agent Shift")
plt.ylabel("Average CSAT Score")

plt.ylim(1,5)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected to compare the average CSAT score across different agent shifts. This visualization helps understand whether the time of support operations influences customer satisfaction levels and highlights which shift performs better in handling customer issues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average customer satisfaction score across different agent shifts. If one shift consistently shows higher CSAT scores, it may indicate better service quality or faster issue resolution during that period. Conversely, lower scores in certain shifts may suggest operational challenges such as higher workload or fewer resources.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help improve business operations by identifying which shifts perform better in terms of customer satisfaction. If certain shifts have lower CSAT scores, management can investigate possible causes such as staffing levels, training needs, or workload distribution. Addressing these issues can improve service quality and enhance customer satisfaction. However, if the lower-performing shifts are not addressed, it may lead to poor customer experiences and negatively impact customer loyalty and brand reputation.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(10,6))

avg_csat_product = df.groupby('Product_category')['CSAT Score'].mean().sort_values(ascending=False)

sns.barplot(x=avg_csat_product.values, y=avg_csat_product.index)

plt.title("Average CSAT Score by Product Category")
plt.xlabel("Average CSAT Score")
plt.ylabel("Product Category")

plt.xlim(1,5)
plt.xticks([1,2,3,4,5])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to compare the average CSAT score across different product categories. This visualization helps identify whether customer satisfaction varies depending on the type of product involved in the support request.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average customer satisfaction score for different product categories. Categories with higher CSAT scores indicate better service experience or fewer complications during issue resolution. Lower CSAT scores in certain product categories may suggest more complex issues or delays in resolving customer problems.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help the business identify product categories that require improvement in customer support processes. If certain categories consistently show lower CSAT scores, the company can investigate the root causes such as product complexity, support delays, or lack of agent expertise. Addressing these issues can improve service quality and increase customer satisfaction. If such issues are ignored, it may lead to customer frustration and negatively affect brand trust and retention.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(x='response_time_minutes', y='CSAT Score', data=df_clean, alpha=0.5)

plt.title("Response Time vs CSAT Score")
plt.xlabel("Response Time (Minutes)")
plt.ylabel("CSAT Score")

plt.ylim(1,5)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen to analyze the relationship between response time and customer satisfaction score. This type of visualization helps observe patterns or trends between how quickly issues are responded to and the resulting customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how CSAT scores vary with response time. If the points indicate that higher CSAT scores occur at lower response times, it suggests that faster responses lead to better customer satisfaction. If response times increase while CSAT scores decrease, it indicates that delayed responses negatively impact the customer experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help businesses improve customer service efficiency by reducing response times. Faster responses can lead to higher customer satisfaction and better customer retention. However, if response times are consistently high and CSAT scores are low, it indicates inefficiencies in support operations that could negatively affect customer trust and long-term business growth.

# %% [markdown]
# #### Chart - 10

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Tenure Bucket', y='CSAT Score', data=df)

plt.title("Average CSAT Score by Agent Tenure")
plt.xlabel("Agent Tenure Bucket")
plt.ylabel("Average CSAT Score")

plt.ylim(1,5)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to compare the average CSAT scores across different agent tenure groups. This visualization helps understand whether agent experience influences customer satisfaction levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how customer satisfaction varies across agents with different tenure levels. If agents with longer tenure have higher CSAT scores, it suggests that experience improves problem-solving ability and communication with customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help businesses understand the impact of agent experience on customer satisfaction. If experienced agents consistently achieve higher CSAT scores, companies may invest more in training programs to help new agents improve faster. However, if newer agents consistently receive lower CSAT scores, it may indicate insufficient training or support, which could negatively impact customer experience and business growth if not addressed.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(10,6))

top_cities = df['Customer_City'].value_counts().head(10).index
city_data = df[df['Customer_City'].isin(top_cities)]

sns.barplot(x='CSAT Score', y='Customer_City', data=city_data)

plt.title("Average CSAT Score by Top Customer Cities")
plt.xlabel("Average CSAT Score")
plt.ylabel("Customer City")

plt.xlim(1,5)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to compare customer satisfaction scores across different cities. This visualization helps identify whether geographic location influences customer experience and service quality.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the average CSAT scores for the top customer cities. Differences in satisfaction levels across cities may indicate variations in service efficiency, delivery performance, or support quality in different regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help businesses identify regions where customer satisfaction is lower and improve service operations in those areas. By addressing region-specific issues such as delivery delays or support response times, companies can improve customer experience. However, if certain cities consistently show lower CSAT scores, it may indicate operational inefficiencies that could negatively affect customer loyalty and brand reputation in those regions.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(8,6))

corr = df_clean[['CSAT Score','Item_price','response_time_minutes']].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap of Numerical Variables")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap was chosen to visualize the correlation between numerical variables in the dataset. This chart helps identify whether variables such as item price and response time have any relationship with customer satisfaction scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the correlation values between the numerical variables. A higher positive value indicates a stronger positive relationship, while a negative value indicates an inverse relationship. This helps determine whether variables like response time or item price influence customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact by identifying operational factors that influence customer satisfaction. For example, if response time shows a negative correlation with CSAT score, it indicates that slower responses lead to lower satisfaction. Businesses can use this information to improve support efficiency and reduce response times. If such operational issues are not addressed, they may negatively impact customer satisfaction and overall brand perception.

# %% [markdown]
# #### Chart - 13

# %%
plt.figure(figsize=(12,6))

sns.boxplot(x='channel_name', y='CSAT Score', hue='category', data=df)

plt.title("CSAT Score Distribution by Support Channel and Issue Category")
plt.xlabel("Support Channel")
plt.ylabel("CSAT Score")

plt.ylim(1,5)

plt.legend(title="Issue Category", bbox_to_anchor=(1.05,1))

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was selected to visualize the distribution of CSAT scores across different support channels and issue categories simultaneously. This chart helps analyze how customer satisfaction varies depending on both the support channel used and the type of issue reported.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how CSAT scores differ across support channels such as inbound, outcall, and email while also considering different issue categories. This helps identify which channels perform better for specific types of issues and whether certain channels consistently deliver higher customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help improve customer support operations by identifying the most effective communication channels for handling different issue categories. For example, if certain issue types receive higher satisfaction scores through a specific channel, the company can prioritize routing those issues through that channel. If certain channels consistently show lower CSAT scores, it may indicate inefficiencies that need improvement to prevent negative customer experiences and potential loss of customers.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
plt.figure(figsize=(10,6))

numeric_df = df.select_dtypes(include=['int64','float64'])

corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen to visualize the relationships between all numerical variables in the dataset simultaneously. This type of chart helps identify whether any variables have strong positive or negative relationships with each other, which is useful for understanding potential factors influencing customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap displays correlation values between numerical variables such as CSAT Score, item price, and response time. Most variables show weak correlations with each other, indicating that customer satisfaction is not strongly influenced by a single numerical factor alone. Instead, satisfaction may depend on a combination of operational and categorical variables.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
sns.pairplot(
    df_clean[['CSAT Score','Item_price','response_time_minutes']],
    diag_kind='hist'
)

plt.suptitle("Pair Plot of Numerical Variables", y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen to visualize the relationships between multiple numerical variables simultaneously. This chart helps understand how variables such as CSAT score, item price, and response time interact with each other and whether any patterns or correlations exist.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows the distribution of each numerical variable and the relationships between them. The scatter plots indicate that there is no strong linear relationship between item price and CSAT score, while response time may have a slight negative relationship with customer satisfaction. This suggests that response delays may influence customer satisfaction more than product price.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To improve customer satisfaction (CSAT), the company should focus on optimizing customer support operations and addressing the key factors influencing customer experience. The analysis shows that response time has a slight negative relationship with CSAT score, indicating that faster responses can improve customer satisfaction. Therefore, reducing response time through better agent allocation and efficient issue handling can positively impact customer experience.
#
# Additionally, certain issue categories and sub-categories contribute to a large portion of customer complaints, such as return requests and order-related queries. Improving resolution processes for these issues can help reduce customer frustration and improve satisfaction levels. Training agents to handle frequent issue types more effectively may also enhance service quality.
#
# The company should also analyze support channel performance and allocate resources to channels that provide higher satisfaction levels. Continuous monitoring of customer feedback and operational metrics will help identify areas requiring improvement. By improving support efficiency, reducing response time, and strengthening issue resolution processes, the business can enhance customer satisfaction and maintain long-term customer loyalty.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, exploratory data analysis was performed on the customer support dataset to understand the factors influencing customer satisfaction (CSAT). The analysis included studying the distribution of different variables, identifying missing values, and examining relationships between features such as support channels, issue categories, response time, and customer satisfaction scores.
#
# The visualizations revealed that most CSAT scores are concentrated between 4 and 5, indicating generally high customer satisfaction levels. However, certain issue categories and operational factors such as response time show variations in satisfaction levels. This suggests that improving response efficiency and optimizing support processes can positively impact customer experience.
#
# Overall, the dataset provides valuable insights into customer support performance. The findings from the exploratory data analysis help identify key factors affecting CSAT scores and provide a strong foundation for building machine learning models to predict customer satisfaction in the next stage of the project.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
